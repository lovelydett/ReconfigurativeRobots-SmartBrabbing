# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pylab inline
# %matplotlib inline
count = 1
def segmentation(datasetPath,imgName):
    print("processing: "+datasetPath+imgName)
    origin_img = cv2.imread(datasetPath+imgName)
    #plt.imshow(origin_img)
    img = origin_img.copy()


    #增亮度
    M=np.ones(img.shape,dtype='uint8')*80
    img=cv2.add(M,img)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # #先获取白色背景

    # gray_values = []
    # for i in range(gray.shape[0]):
    #     for j in range(gray.shape[1]):
    #         gray_values.append(gray[i][j])
    # gray_values.sort()
    # mid_value = gray_values[int(len(gray_values)/2)]
    # print(mid_value)

    # for i in range(gray.shape[0]):
    #     for j in range(gray.shape[1]):
    #         if gray[i][j]>mid_value:
    #             gray[i][j] = 255
    #         else:
    #             gray[i][j] = 0

    #转灰度 高糊
    blurred = cv2.GaussianBlur(gray, (9, 9),0) 
    ret,blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    blurred = cv2.GaussianBlur(blurred, (9, 9),0) 
    ret,blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    blurred = cv2.GaussianBlur(blurred, (9, 9),0) 
    ret,blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    plt.imshow(blurred)

    # #提取梯度
    # gradX = cv2.Sobel(blurred, ddepth=cv2.CV_32F, dx=1, dy=0)
    # gradY = cv2.Sobel(blurred, ddepth=cv2.CV_32F, dx=0, dy=1)

    # gradient = cv2.subtract(gradX, gradY)
    # gradient = cv2.convertScaleAbs(gradient)

    # plt.imshow(gradient)


    #blurred = cv2.GaussianBlur(gradient, (9, 9),0)
    (_, thresh) = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    plt.imshow(thresh)

    #腐蚀膨胀的核
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (25, 25))
    closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
    plt.imshow(closed)

    #腐蚀膨胀
    closed = cv2.erode(closed, None, iterations=4)
    closed = cv2.dilate(closed, None, iterations=4)
    plt.imshow(closed)

    #分割
    (_,contours,_) = cv2.findContours(closed,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE,)
    #print(len(contours))

    #在原图上绘图
    img = origin_img.copy()
    global count
    for c in contours:
        if cv2.arcLength(c, True) >500 and cv2.arcLength(c, True) < 2000 :
            #print(cv2.arcLength(c, True))
            (x, y, w, h) = cv2.boundingRect(c)
            cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 8)
            crop_img= origin_img[y:y+h, x:x+w]
            cv2.imwrite('imgProcessed/test_from_segmentation/'+str(count)+".jpg",crop_img) 
            count+=1
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datasetPath = "../../data/imgSaved/test_pure/"
count = 1
with open(datasetPath+'names.txt') as file:
    for line in file.readlines():
        if line is not "":
            img = cv2.imread(datasetPath+line.replace("\n",""))
            #print(np.array(img).shape)
            segmentation(datasetPath,line.replace("\n",""))
# Out:
# processing: ../../data/imgSaved/test_pure/ (100).jpg
# 17
# processing: ../../data/imgSaved/test_pure/ (101).jpg
# 15
# processing: ../../data/imgSaved/test_pure/ (102).jpg
# 16
# processing: ../../data/imgSaved/test_pure/ (103).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (104).jpg
# 13
# processing: ../../data/imgSaved/test_pure/ (105).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (106).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (107).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (108).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (109).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (10).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (110).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (111).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (112).jpg
# 17
# processing: ../../data/imgSaved/test_pure/ (113).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (114).jpg
# 16
# processing: ../../data/imgSaved/test_pure/ (115).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (116).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (117).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (118).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (119).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (11).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (120).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (12).jpg
# 26
# processing: ../../data/imgSaved/test_pure/ (13).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (14).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (15).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (16).jpg
# 29
# processing: ../../data/imgSaved/test_pure/ (17).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (18).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (19).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (1).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (20).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (21).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (22).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (23).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (24).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (25).jpg
# 16
# processing: ../../data/imgSaved/test_pure/ (26).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (27).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (28).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (29).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (2).jpg
# 26
# processing: ../../data/imgSaved/test_pure/ (30).jpg
# 27
# processing: ../../data/imgSaved/test_pure/ (31).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (32).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (33).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (34).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (35).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (36).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (37).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (38).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (39).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (3).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (40).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (41).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (42).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (43).jpg
# 29
# processing: ../../data/imgSaved/test_pure/ (44).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (45).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (46).jpg
# 26
# processing: ../../data/imgSaved/test_pure/ (47).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (48).jpg
# 19
# processing: ../../data/imgSaved/test_pure/ (49).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (4).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (50).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (51).jpg
# 15
# processing: ../../data/imgSaved/test_pure/ (52).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (53).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (54).jpg
# 17
# processing: ../../data/imgSaved/test_pure/ (55).jpg
# 14
# processing: ../../data/imgSaved/test_pure/ (56).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (57).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (58).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (59).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (5).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (60).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (61).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (62).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (63).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (64).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (65).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (66).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (67).jpg
# 28
# processing: ../../data/imgSaved/test_pure/ (68).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (69).jpg
# 26
# processing: ../../data/imgSaved/test_pure/ (6).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (70).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (71).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (72).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (73).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (74).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (75).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (76).jpg
# 24
# processing: ../../data/imgSaved/test_pure/ (77).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (78).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (79).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (7).jpg
# 28
# processing: ../../data/imgSaved/test_pure/ (80).jpg
# 19
# processing: ../../data/imgSaved/test_pure/ (81).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (82).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (83).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (84).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (85).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (86).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (87).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (88).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (89).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (8).jpg
# 23
# processing: ../../data/imgSaved/test_pure/ (90).jpg
# 25
# processing: ../../data/imgSaved/test_pure/ (91).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (92).jpg
# 21
# processing: ../../data/imgSaved/test_pure/ (93).jpg
# 22
# processing: ../../data/imgSaved/test_pure/ (94).jpg
# 15
# processing: ../../data/imgSaved/test_pure/ (95).jpg
# 16
# processing: ../../data/imgSaved/test_pure/ (96).jpg
# 15
# processing: ../../data/imgSaved/test_pure/ (97).jpg
# 17
# processing: ../../data/imgSaved/test_pure/ (98).jpg
# 20
# processing: ../../data/imgSaved/test_pure/ (99).jpg
# 18
# processing: ../../data/imgSaved/test_pure/ (9).jpg
# 20

# %%
img = cv2.imread("../../data/imgSaved/test_pure/ (100).jpg")
np.array(img).shape
# Out:
# (1080, 1920, 3)
