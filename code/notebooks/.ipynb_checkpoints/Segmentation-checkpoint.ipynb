# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pylab inline
# %matplotlib inline
img = cv2.imread('../../data/imgSaved/20191013/119.jpg')


#增亮度
M=np.ones(img.shape,dtype='uint8')*80
img=cv2.add(M,img)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# #先获取白色背景

# gray_values = []
# for i in range(gray.shape[0]):
#     for j in range(gray.shape[1]):
#         gray_values.append(gray[i][j])
# gray_values.sort()
# mid_value = gray_values[int(len(gray_values)/2)]
# print(mid_value)

# for i in range(gray.shape[0]):
#     for j in range(gray.shape[1]):
#         if gray[i][j]>mid_value:
#             gray[i][j] = 255
#         else:
#             gray[i][j] = 0
            
blurred = cv2.GaussianBlur(gray, (9, 9),0) 
blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blurred = cv2.GaussianBlur(blurred, (9, 9),0) 
blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blurred = cv2.GaussianBlur(blurred, (9, 9),0) 
blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blurred = cv2.GaussianBlur(blurred, (9, 9),0) 
blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blurred = cv2.GaussianBlur(blurred, (9, 9),0) 
blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.imshow(blurred)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-b5a67d977617> in <module>
#      29 blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#      30
# ---> 31 blurred = cv2.GaussianBlur(blurred, (9, 9),0)
#      32 blurred = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#      33
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'

# %%
#转灰度 高糊
# contours,_= cv2.findContours(blurred,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)    # 输出为三个参数 
# print(len(contours))
# for c in contours:
#     if cv2.arcLength(c, True) >10:
#         print(cv2.arcLength(c, True))
#         (x, y, w, h) = cv2.boundingRect(c)
#         cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 8)
# #cv2.drawContours(img,contours,-1,(0,0,255),3)
# plt.imshow(img)

# %%
#提取梯度
gradX = cv2.Sobel(gray, ddepth=cv2.CV_32F, dx=1, dy=0)
gradY = cv2.Sobel(gray, ddepth=cv2.CV_32F, dx=0, dy=1)

gradient = cv2.subtract(gradX, gradY)
gradient = cv2.convertScaleAbs(gradient)

plt.imshow(gradient)

# %%
#blurred = cv2.GaussianBlur(gradient, (9, 9),0)
(_, thresh) = cv2.threshold(blurred, 0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(thresh)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (25, 25))
closed = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
plt.imshow(closed)

# %%
closed = cv2.erode(closed, None, iterations=2)
closed = cv2.dilate(closed, None, iterations=2)
plt.imshow(closed)

# %%
(contours, _) = cv2.findContours(closed,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE,)
print(len(contours))
# Out:
# 21

# %%
for c in contours:
    print("周长：",cv2.arcLength(c, True))
    print("面积：",cv2.contourArea(c,True))
# Out:
# 周长： 75.11269783973694
# 面积： -331.0
# 周长： 186.3675309419632
# 面积： -1016.0
# 周长： 93.01219260692596
# 面积： -375.5
# 周长： 74.3847758769989
# 面积： -250.5
# 周长： 56.97056233882904
# 面积： -173.0
# 周长： 50.97056245803833
# 面积： -159.0
# 周长： 18.82842707633972
# 面积： -24.0
# 周长： 549.9655102491379
# 面积： -7314.0
# 周长： 43.071067690849304
# 面积： -77.5
# 周长： 367.0538226366043
# 面积： -1807.0
# 周长： 14.0
# 面积： -10.0
# 周长： 7155.884674191475
# 面积： -1748110.0
# 周长： 696.3401815891266
# 面积： 27310.5
# 周长： 877.5950148105621
# 面积： 52334.5
# 周长： 504.0731545686722
# 面积： 15116.0
# 周长： 870.5067030191422
# 面积： 49082.5
# 周长： 701.0437185764313
# 面积： 32467.0
# 周长： 152.22539579868317
# 面积： 1554.0
# 周长： 90.6690468788147
# 面积： 583.5
# 周长： 261.663996219635
# 面积： 2740.5
# 周长： 688.9259675741196
# 面积： 25626.0

# %%
img = cv2.imread('../../data/imgSaved/20191013/119.jpg')
img = img.copy()
for c in contours:
    if cv2.arcLength(c, True) >500 and cv2.arcLength(c, True) < 3500 :
        print(cv2.arcLength(c, True))
        (x, y, w, h) = cv2.boundingRect(c)
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 8)
#cv2.drawContours(img,contours,-1,(0,0,255),3)
plt.imshow(img)
# Out:
# 549.9655102491379
# 696.3401815891266
# 877.5950148105621
# 504.0731545686722
# 870.5067030191422
# 701.0437185764313
# 688.9259675741196
